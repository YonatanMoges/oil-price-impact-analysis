# %%
import pandas as pd
import sys
sys.path.append('../scripts') 

from price_analysis import PriceAnalysis

# %%
# Load oil price data
oil_data = pd.read_csv('../data/BrentOilPrices.csv')

# %% [markdown]
# Initialize analysis class without preloaded economic data

# %%
analysis = PriceAnalysis(oil_data)

# %% [markdown]
# Fetch economic data from the World Bank API

# %%
analysis.fetch_economic_data(start_year=1987, end_year=2022)
# Out:
#                      GDP   Inflation  Unemployment  Exchange Rate
# date
# 1987-01-01  4.855215e+12   52.108294           NaN            1.0
# 1988-01-01  5.236438e+12   54.233135           NaN            1.0
# 1989-01-01  5.641580e+12   56.850970           NaN            1.0
# 1990-01-01  5.963144e+12   59.919760           NaN            1.0
# 1991-01-01  6.158129e+12   62.457341         6.800            1.0
# 1992-01-01  6.520327e+12   64.349061         7.500            1.0
# 1993-01-01  6.858559e+12   66.248425         6.900            1.0
# 1994-01-01  7.287236e+12   67.975813         6.119            1.0
# 1995-01-01  7.639749e+12   69.882820         5.650            1.0
# 1996-01-01  8.073122e+12   71.931229         5.451            1.0
# 1997-01-01  8.577552e+12   73.612758         5.000            1.0
# 1998-01-01  9.062817e+12   74.755433         4.511            1.0
# 1999-01-01  9.631172e+12   76.391102         4.219            1.0
# 2000-01-01  1.025095e+13   78.970721         3.992            1.0
# 2001-01-01  1.058193e+13   81.202568         4.731            1.0
# 2002-01-01  1.092911e+13   82.490467         5.783            1.0
# 2003-01-01  1.145645e+13   84.363079         5.989            1.0
# 2004-01-01  1.221720e+13   86.621678         5.529            1.0
# 2005-01-01  1.303920e+13   89.560532         5.084            1.0
# 2006-01-01  1.381558e+13   92.449705         4.623            1.0
# 2007-01-01  1.447423e+13   95.086992         4.622            1.0
# 2008-01-01  1.476986e+13   98.737477         5.784            1.0
# 2009-01-01  1.447807e+13   98.386420         9.254            1.0
# 2010-01-01  1.504897e+13  100.000000         9.633            1.0
# 2011-01-01  1.559973e+13  103.156842         8.949            1.0
# 2012-01-01  1.625397e+13  105.291505         8.069            1.0
# 2013-01-01  1.688068e+13  106.833849         7.375            1.0
# 2014-01-01  1.760814e+13  108.566932         6.168            1.0
# 2015-01-01  1.829502e+13  108.695722         5.280            1.0
# 2016-01-01  1.880491e+13  110.067009         4.869            1.0
# 2017-01-01  1.961210e+13  112.411557         4.355            1.0
# 2018-01-01  2.065652e+13  115.157303         3.896            1.0
# 2019-01-01  2.152140e+13  117.244195         3.669            1.0
# 2020-01-01  2.132295e+13  118.690502         8.055            1.0
# 2021-01-01  2.359403e+13  124.266414         5.349            1.0
# 2022-01-01  2.574411e+13  134.211206         3.650            1.0

# %% [markdown]
# Data Preprocessing

# %%
analysis.preprocess_data()

# %% [markdown]
# Exploratory Data Analysis

# %%
analysis.exploratory_data_analysis()
